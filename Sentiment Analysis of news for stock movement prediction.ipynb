# %% [markdown]
# ## Install packages

# %%
pip install feedparser
# Out:
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6071 sha256=63eeb3bec62f830a961015beec723e9b59338220e281cbfc2d2d18df7fb73210
#   Stored in directory: c:\users\venug\appdata\local\pip\cache\wheels\83\63\2f\117884c3b19d46b64d3d61690333aa80c88dc14050e269c546
# Successfully built sgmllib3k
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import packages

# %%
import feedparser
import requests
from bs4 import BeautifulSoup
import pandas as pd
#NLP packages
from textblob import TextBlob
pd.set_option('display.max_colwidth', 300)

# %% [markdown]
# ## Define RSS feed sources

# %%
news_source = []
news_title = []
news_summary = []
allnews = []

newsurls = {
    'googlenews': 'https://news.google.com/rss?hl=en-IN&amp;ned=us&amp;gl=IN&gl=IN&ceid=IN:en',
    'cnnnews': 'http://rss.cnn.com/rss/cnn_topstories.rss',
    'financialnews' : 'https://in.investing.com/rss/news.rss',
    'cnbcnews' : 'https://www.cnbc.com/id/100003114/device/rss/rss.html',
    'cnbcworld': 'https://www.cnbc.com/id/100727362/device/rss/rss.html',
    'goodreturns' : 'https://www.goodreturns.in/rss/goodreturns-fb.xml', 
    'mctopnews' : 'http://www.moneycontrol.com/rss/MCtopnews.xml',
    'mclatestnews' : 'http://www.moneycontrol.com/rss/latestnews.xml',
    'mcbussiness' : 'http://www.moneycontrol.com/rss/business.xml',
    'mcmf' : 'http://www.moneycontrol.com/rss/mfcolumns.xml',
    'mcstocks' : 'http://www.moneycontrol.com/rss/buzzingstocks.xml',
    'mcmarket' : 'http://www.moneycontrol.com/rss/marketreports.xml',
    'mcadrs' : 'http://www.moneycontrol.com/rss/indianadrs.xml',
    'mcinternational' : 'http://www.moneycontrol.com/rss/internationalmarkets.xml',
    'mcmarketedge' : 'http://www.moneycontrol.com/rss/marketedge.xml',
    'mcoutlook' : 'http://www.moneycontrol.com/rss/marketoutlook.xml',
    'mctech' : 'http://www.moneycontrol.com/rss/technicals.xml',
    'mcipo' : 'http://www.moneycontrol.com/rss/iponews.xml',
    'mcinsure' : 'http://www.moneycontrol.com/rss/insurancenews.xml',
    'mcmfnews' : 'http://www.moneycontrol.com/rss/mfnews.xml',
    'mcresults' : 'http://www.moneycontrol.com/rss/results.xml',
    'mctechno' : 'http://www.moneycontrol.com/rss/technology.xml',
    'mcentertain' : 'http://www.moneycontrol.com/rss/entertainment.xml',
    'mcworld' : 'http://www.moneycontrol.com/rss/worldnews.xml',
    'mccurrent' : 'http://www.moneycontrol.com/rss/currentaffairs.xml',
    'etnews' : 'https://economictimes.indiatimes.com/news/rssfeeds/1715249553.cms',
    'etmarket' : 'https://economictimes.indiatimes.com/markets/rssfeeds/1977021501.cms',
    'etwealth' : 'https://economictimes.indiatimes.com/wealth/rssfeeds/837555174.cms',
    'etmf' : 'https://economictimes.indiatimes.com/mf/rssfeeds/359241701.cms',
    'etopinion' : 'https://economictimes.indiatimes.com/opinion/rssfeeds/897228639.cms',
    'etjobs' : 'https://economictimes.indiatimes.com/jobs/rssfeeds/107115.cms',
    'etsmallbiz' : 'https://economictimes.indiatimes.com/small-biz/rssfeeds/5575607.cms',
    'etrss' : 'https://economictimes.indiatimes.com/rssfeedsdefault.cms',
    'etstock' : 'https://economictimes.indiatimes.com/markets/stocks/rssfeeds/2146842.cms',
    'etlatest' : 'https://economictimes.indiatimes.com/news/latest-news/rssfeeds/20989204.cms',
    'eteco' : 'https://economictimes.indiatimes.com/news/economy/rssfeeds/1373380680.cms',
    'etcompany' : 'https://economictimes.indiatimes.com/news/company/rssfeeds/2143429.cms',
    'etstocks1' : 'https://economictimes.indiatimes.com/et-now/stocks/rssfeedsvideo/4413765.cms',
    'cnbc' : 'https://www.cnbc.com/id/100003114/device/rss/rss.html',
    'cnbc' : 'https://www.cnbc.com/id/100727362/device/rss/rss.html',
    'cnbc' : 'https://www.cnbc.com/id/10001147/device/rss/rss.html',
    'cnbc' : 'https://www.cnbc.com/id/19832390/device/rss/rss.html',
    'cnbc' : 'https://www.cnbc.com/id/10000664/device/rss/rss.html',
    'cnbc' : 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
    'cnbc' : 'https://www.cnbc.com/id/10000101/device/rss/rss.html',
    'cnbc' : 'https://www.cnbc.com/id/10000110/device/rss/rss.html',
    'cnbc' : 'https://www.cnbc.com/id/44877279/device/rss/rss.html',
    'cnbc' : 'https://www.cnbc.com/id/10000739/device/rss/rss.html',
    'cnbc' : 'https://www.cnbc.com/id/10000113/device/rss/rss.html',
    'indinfo' : 'https://www.indiainfoline.com/rss/news.xml',
    'indinfo' : 'https://www.indiainfoline.com/rss/resultexpress.xml',
    'invest' : 'https://in.investing.com/rss/news.rss',
    'invest' : 'https://in.investing.com/rss/news_25.rss',
    'invest' : 'https://in.investing.com/rss/news_477.rss',
    'invest' : 'https://in.investing.com/rss/news_95.rss',
    'nse' : 'http://feeds.feedburner.com/nseindia/ann',
    'nse' : 'http://feeds.feedburner.com/nseindia/boardmeet',
    'nse' : 'http://feeds.feedburner.com/nseindia/results',
    'nse' : 'http://feeds.feedburner.com/nseindia/ca',
    'nse' : 'http://feeds.feedburner.com/nseindia/UxpO',
    'nse' : 'http://feeds.feedburner.com/nseindia/circulars',
    'equitym' : 'http://feeds.equitymaster.com/TodaysMarket?format=HTML',
    'equitym' : 'http://feeds.equitymaster.com/EQTM?format=HTML',
    'equitym' : 'http://feeds.feedburner.com/CompaniesResultsByEquitymaster?format=HTML',
    'bt' : 'https://www.businesstoday.in/rss/rssstory.jsp?sid=105',
    'bt' : 'https://www.businesstoday.in/rss/rssstory.jsp?sid=105',
    'bt' : 'https://www.businesstoday.in/rss/rssstory.jsp?sid=111',
    'bt' : 'https://www.businesstoday.in/rss/rssstory.jsp?sid=110',
    'mw' : 'http://www.marketwatch.com/rss/topstories',
    'mw' : 'http://www.marketwatch.com/rss/realtimeheadlines',
    'mw' : 'http://www.marketwatch.com/rss/financial',
    'mw' : 'http://feeds.marketwatch.com/marketwatch/bulletins',
    'seekingalpha' : 'https://seekingalpha.com/market_currents.xml',
    'smw' : 'https://stockmarketnews.today/feed/',
    'smw' : 'hhttps://stocksnewsfeed.com/feed/',
    'fool' : 'https://www.fool.co.uk/feed/',
    'ino' : 'https://www.ino.com/blog/feed/',
    'investing' : 'https://www.investing.com/rss/news.rss',
    'reddit' : 'https://www.reddit.com/r/StockMarket/.rss',
    'reddit' : 'https://www.reddit.com/r/stocks/.rss',
}

# %% [markdown]
# ## Extract news headlines from different sources and store in a table

# %%
for key, rss_url in newsurls.items():
    feed = feedparser.parse(rss_url)
    for newsitem in feed['items']:
        news_source.append(key)
        news_title.append(newsitem['title'])

data = pd.DataFrame(list(zip(news_source, news_title)), columns =['News_Source', 'News_Title']) 
data
# Out:
#      News_Source  \
# 0     googlenews
# 1     googlenews
# 2     googlenews
# 3     googlenews
# 4     googlenews
# ...          ...
# 2525      reddit
# 2526      reddit
# 2527      reddit
# 2528      reddit
# 2529      reddit
#
#                                                                                                         News_Title
# 0              Amit Shah's praise for Modi a joke, says tennis legend Martina Navratilova - The New Indian Express
# 1                                            Coal shortage: Amit Shah meets power, coal ministers - Times of India
# 2                                         Encounter On Between Security Forces, Terrorists In J&K's Shopian - NDTV
# 3                Ashish Mishra remanded in 3-day police custody in Lakhimpur Kheri violence case - Hindustan Times
# 4        Nobel Prize 2021 in Economics awarded to David Card, Joshua Angrist and Guido Imbens - The Indian Express
# ...

# %% [markdown]
# ## Find sentiment of news headlines (polarity & subjectivity)

# %%
#Calculating the Sentiment Polarity
polarity=[] # list which will contain the polarity of the comments
subjectivity=[] # list which will contain the subjectivity of the comments
for i in data['News_Title'].values:
    try:
        analysis =TextBlob(i)
        polarity.append(analysis.sentiment.polarity)
        subjectivity.append(analysis.sentiment.subjectivity)
        
    except:
        polarity.append(0)
        subjectivity.append(0)
        
#Adding the Sentiment Polarity column to the data
data['polarity']=polarity
data['subjectivity']=subjectivity
data
# Out:
#      News_Source  \
# 0     googlenews
# 1     googlenews
# 2     googlenews
# 3     googlenews
# 4     googlenews
# ...          ...
# 2525      reddit
# 2526      reddit
# 2527      reddit
# 2528      reddit
# 2529      reddit
#
#                                                                                                         News_Title  \
# 0              Amit Shah's praise for Modi a joke, says tennis legend Martina Navratilova - The New Indian Express
# 1                                            Coal shortage: Amit Shah meets power, coal ministers - Times of India
# 2                                         Encounter On Between Security Forces, Terrorists In J&K's Shopian - NDTV
# 3                Ashish Mishra remanded in 3-day police custody in Lakhimpur Kheri violence case - Hindustan Times
# 4        Nobel Prize 2021 in Economics awarded to David Card, Joshua Angrist and Guido Imbens - The Indian Express
# ...

# %% [markdown]
# ## Save news headlines and sentiment in a csv file

# %%
data.to_csv('news_headlines_polarity.csv')
